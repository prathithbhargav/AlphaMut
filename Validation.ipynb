# %% [markdown]
# # WITH PROLINE

# %%
# for protein structural modelling
from modeller import *
from modeller.automodel import *
from Bio.SVDSuperimposer import SVDSuperimposer
import numpy as np
import biovec
import pickle
import glob
from tqdm import tqdm
# from utils functions
from utils.encoder_decoder import *
from utils.sequence import *
from utils.reward import *
from utils.environment import *

# for deep learning
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# for envronment creation
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import MultiDiscrete
from gymnasium.spaces import Discrete
from gymnasium.spaces import Box

#for reading PDB files and processing them
from biopandas.pdb import PandasPdb
import pandas as pd
from utils.sequence import *

# for generating structures through esm instead of modeller
import esm
import biotite.structure as struc
import biotite.structure.io as strucio

# for general utility
import random
import os
import subprocess
import time
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.dpi'] = 200
plt.style.use('seaborn')
plt.rcParams.update({"text.usetex": True})

# %% [markdown]
# # WITHOUT PROLINE

# %%
# for protein structural modelling
from modeller import *
from modeller.automodel import *
from Bio.SVDSuperimposer import SVDSuperimposer
import numpy as np
import biovec
import pickle
import glob
from tqdm import tqdm
# from utils functions
from utils.encoder_decoder_no_proline import *
from utils.sequence import *
from utils.reward import *
from utils.environment_no_proline import *

# for deep learning
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# for envronment creation
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import MultiDiscrete
from gymnasium.spaces import Discrete
from gymnasium.spaces import Box

#for reading PDB files and processing them
from biopandas.pdb import PandasPdb
import pandas as pd
from utils.sequence import *

# for generating structures through esm instead of modeller
import esm
import biotite.structure as struc
import biotite.structure.io as strucio

# for general utility
import random
import os
import subprocess
import time
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.dpi'] = 200
plt.style.use('seaborn')
plt.rcParams.update({"text.usetex": True})

# %%
def plot_rewards(array_name,window_size):
    df = pd.DataFrame(array_name,columns=['reward'])
    rolling_average_reward = df['reward'].rolling(window=window_size).mean().dropna()
    plt.plot(rolling_average_reward)
    plt.ylabel(f'Rolling average of total rewards (window = {window_size})')
    plt.xlabel('Number of episodes')

# %%
class PolicyNetwork():
    def __init__(self, n_state, n_action, n_hidden=50,lr=0.001,entropy_weight=0.01):
        self.model = nn.Sequential(nn.Linear(n_state, n_hidden),
                                   nn.ReLU(),
                                   nn.Linear(n_hidden, n_action),
                                   nn.Softmax(dim=-1), )
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr)
        self.entropy_weight = entropy_weight
    def predict(self, s):
        return self.model(torch.Tensor(s))
    def update(self, returns, log_probs,entropies):
        policy_gradient = []
        for log_prob, Gt, entropy in zip(log_probs, returns, entropies):
            policy_gradient.append((-log_prob * Gt) + (self.entropy_weight * entropy))
        loss = torch.stack(policy_gradient).sum()
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
    def get_action(self, s):

        probs = self.predict(s)
        action = torch.multinomial(probs, 1).item()
        log_prob = torch.log(probs[action])
        entropy = -torch.sum(probs * torch.log(probs + 1e-9))  # Calculate entropy
        return action, log_prob, entropy

# %%
# this is the evaluation model
def evaluate_model(estimator, env, num_episodes):
    total_reward_episode = [0] * num_episodes
    actions_taken_in_episodes = {}
    number_of_mutations_per_episode = [0] * num_episodes
    file_chosen_for_mutations = {}
    for episode in tqdm(range(num_episodes)):
        actions_taken_in_episodes[episode] = []
        file_chosen_for_mutations[episode] = [0]
        rewards = []
        
        state, info,dummy = env.reset()
        while True:
            action, log_prob, entropy = estimator.get_action(state)
            next_state, reward, terminated, truncated, info = env.step(action)
            total_reward_episode[episode] += reward
            rewards.append(reward)
            name_of_the_protein = os.path.basename(env.path_of_template_pdb_file),
            actions_taken_in_episodes[episode].append(info)
            number_of_mutations_per_episode[episode]+=1
            file_chosen_for_mutations[episode][0] = name_of_the_protein 
            if terminated or truncated:
                break
            state = next_state
#         print(f'{episode} episode done')
    return total_reward_episode,np.mean(total_reward_episode),np.std(total_reward_episode),actions_taken_in_episodes,number_of_mutations_per_episode,file_chosen_for_mutations

# %%
def validate_model(entropy,percentage,training_folder_name,validation_folder_path,validation_folder_code,use_proline = False):
    validation_folder_base_path = os.path.basename(validation_folder_path)
    n_hidden = 128
    lr = 0.0007
    gamma = 0.95
    entropic_factor = float(entropy)
    if use_proline == False:
#         saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_0.0_trained_on_tp_30_training_no_proline.pth
        saved_model_file_path = f'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_{entropy}_co_{percentage}_trained_on_{training_folder_name}_no_proline.pth'
        validation_structures_to_save_path = f'validation_structures/entropy_{entropy}_co_{percentage}_trained_on_{training_folder_name}_validated_on_{validation_folder_code}_no_proline'
        os.makedirs(validation_structures_to_save_path,exist_ok=True)
        env = PeptideEvolutionNoProline(folder_containing_pdb_files=validation_folder_path,
               structure_generator='esm_sse',
               validation=True,
               reward_cutoff=float(percentage),
               unique_path_to_give_for_file='valid',
               folder_to_save_validation_files=validation_structures_to_save_path)
        folder_for_saving_stuff = f'validation_results/entropy_{entropic_factor}_co_{percentage}_trained_on_{training_folder_name}_validated_on_{validation_folder_code}_no_proline'
        os.makedirs(folder_for_saving_stuff,exist_ok=True)
    if use_proline == True:
        saved_model_file_path = f'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_{entropy}_co_{percentage}_trained_on_{training_folder_name}.pth'
        validation_structures_to_save_path = f'validation_structures/entropy_{entropy}_co_{percentage}_trained_on_{training_folder_name}_validated_on_{validation_folder_code}'
        os.makedirs(validation_structures_to_save_path,exist_ok=True)
        env = PeptideEvolution(folder_containing_pdb_files=validation_folder_path,
               structure_generator='esm_sse',
               validation=True,
               reward_cutoff=float(percentage),
               unique_path_to_give_for_file='valid',
               folder_to_save_validation_files=validation_structures_to_save_path)
        folder_for_saving_stuff = f'validation_results/entropy_{entropic_factor}_co_{percentage}_trained_on_{training_folder_name}_validated_on_{validation_folder_code}'
        os.makedirs(folder_for_saving_stuff,exist_ok=True)
        
#     validation_structures_to_save_path = f'validation_structures/entropy_{entropy}_co_{percentage}_trained_on_{training_folder_name}_validated_on_{validation_folder_code}'



    n_state = env.observation_space.shape[0]
    n_action = env.action_space.n

    loaded_estimator = PolicyNetwork(n_state, n_action, n_hidden, lr, entropy_weight=entropic_factor)
    loaded_estimator.model.load_state_dict(torch.load(saved_model_file_path))
    total_reward_array,mean_validation_reward, standard_deviation,actions_taken, mutations_array, files_chosen_for_mutations = evaluate_model(estimator=loaded_estimator, env=env,num_episodes=500)
    folder_for_saving_stuff = f'validation_results/entropy_{entropic_factor}_co_{percentage}_trained_on_{training_folder_name}_validated_on_{validation_folder_code}'
    os.makedirs(folder_for_saving_stuff,exist_ok=True)
    with open(f'{folder_for_saving_stuff}/entropy_{entropic_factor}_co_{percentage}_mutations.pkl','wb') as file:
        pickle.dump(actions_taken,file)
    with open(f'{folder_for_saving_stuff}/entropy_{entropic_factor}_co_{percentage}_files.pkl','wb') as file:
        pickle.dump(files_chosen_for_mutations,file)

# %%
def validate_model_no_proline(entropy,percentage,training_folder_name,validation_folder_path,validation_folder_code):

# %%
entropy_no_proline = 0.0
percentage_no_proline = '50.0'
validate_model(entropy=entropy_no_proline,
              percentage=percentage_no_proline,
              training_folder_name='tp_30_training',
            validation_folder_path='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
              validation_folder_code='tp_30_validate',
              use_proline=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [57:43<00:00,  6.93s/it]

# %%
list_of_percentages = ['30.0','40.0','50.0']
list_of_entropies = ['0.0','0.001','0.0001','1e-05']

# %%
for entropy in list_of_entropies:
    for percentage in list_of_percentages:
        try:
            validate_model(entropy, 
                           percentage,
                           training_folder_name = 'membranome_30_training',
                           validation_folder_path='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
                           validation_folder_code='tp_30_validate')
        except Exception as e:
            print(e)
            print(entropy,percentage)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [48:54<00:00,  5.87s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [37:20<00:00,  4.48s/it]
# [Errno 2] No such file or directory: 'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_0.0_co_50.0_trained_on_membranome_30_training.pth'
# 0.0 50.0
# [Errno 2] No such file or directory: 'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_0.001_co_30.0_trained_on_membranome_30_training.pth'
# 0.001 30.0
# [Errno 2] No such file or directory: 'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_0.001_co_40.0_trained_on_membranome_30_training.pth'
# 0.001 40.0
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [28:57<00:00,  3.48s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [41:48<00:00,  5.02s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [42:41<00:00,  5.12s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [29:37<00:00,  3.56s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [44:21<00:00,  5.32s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [31:28<00:00,  3.78s/it]
# [Errno 2] No such file or directory: 'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_1e-05_co_50.0_trained_on_membranome_30_training.pth'
# 1e-05 50.0

# %%
validate_model(entropy='0.001', 
               percentage='40.0',
               training_folder_name = 'membranome_30_training',
               validation_folder_path='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
               validation_folder_code='tp_30_validate')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [39:42<00:00,  4.76s/it]

# %%
validate_model(entropy='0.001', 
               percentage='30.0',
               training_folder_name = 'membranome_30_training',
               validation_folder_path='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
               validation_folder_code='tp_30_validate')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [47:54<00:00,  5.75s/it]

# %%
validate_model(entropy='0.0', 
               percentage='50.0',
               training_folder_name = 'membranome_30_training',
               validation_folder_path='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
               validation_folder_code='tp_30_validate')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [33:37<00:00,  4.04s/it]

# %%
validate_model(entropy='1e-05', 
               percentage='50.0',
               training_folder_name = 'membranome_30_training',
               validation_folder_path='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
               validation_folder_code='tp_30_validate')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [33:38<00:00,  4.04s/it]

# %%
for files in glob.glob('validation_structures/entropy*/*.pdb'):
    if percentage_of_b(get_structural_annotations(files)) >40 :
        if 'membranome' not in files:
            print(files,percentage_of_b(get_structural_annotations(files)))
# Out:
# validation_structures/entropy_0.0_co_30.0/3mde_A_1_292_321_2024-01-22 12:40:46.pdb 46.666666666666664
# validation_structures/entropy_0.0_co_50.0/2h89_C_1_80_109_2024-01-22 13:35:16.pdb 43.333333333333336
# validation_structures/entropy_0.001_co_30.0/3ayg_A_1_434_463_2024-01-21 00:40:46.pdb 50.0
# validation_structures/entropy_0.001_co_30.0/4kgj_A_1_145_174_2024-01-21 00:32:56.pdb 43.333333333333336
# validation_structures/entropy_0.001_co_30.0/2ycz_A_1_75_104_2024-01-21 00:43:49.pdb 43.333333333333336
# validation_structures/entropy_0.0001_co_30.0/4il6_D_1_108_137_2024-01-21 02:20:30.pdb 60.0
# validation_structures/entropy_0.0001_co_30.0/4il6_D_1_108_137_2024-01-21 02:45:08.pdb 50.0
# validation_structures/entropy_0.0001_co_50.0/4o9r_A_1_312_341_2024-01-21 03:25:57.pdb 66.66666666666666
# validation_structures/entropy_1e-05_co_30.0/1zrt_C_1_89_118_2024-01-21 04:10:48.pdb 43.333333333333336
# validation_structures/entropy_0.001_co_50.0/4il6_D_1_108_137_2024-01-21 01:56:17.pdb 50.0

# %%
env = PeptideEvolution(folder_containing_pdb_files='../DrugResistance/folder_for_machine_learning/tp_30_validate/',
                       structure_generator='esm_sse',
                       validation=True,
                       reward_cutoff=40,
                       unique_path_to_give_for_file='valid',
                       folder_to_save_validation_files='validation_structures')

# %%
n_state = env.observation_space.shape[0]
n_action = env.action_space.n
n_hidden = 128
lr = 0.001
gamma = 0.95
entropic_factor = 0.0

# %%
loaded_estimator = PolicyNetwork(n_state, n_action, n_hidden, lr, entropy_weight=entropic_factor)
loaded_estimator.model.load_state_dict(torch.load('saved_models/saved_rl_model_1_lr_0.001_gamma_0.95_ep_5000_entropic_factor_0.0_trained_on_29_usable.pth'))
# Out:
# <All keys matched successfully>

# %%
total_reward_array,mean_validation_reward, standard_deviation,actions_taken, mutations_array, files_chosen_for_mutations = evaluate_model(estimator=loaded_estimator, env=env,num_episodes=500)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [40:10<00:00,  4.82s/it]

# %%
with open(f'validation_results/0.0.pkl','wb') as file:
    pickle.dump(actions_taken,file)

# %%
files_chosen_for_mutations
# Out:
# [('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('CHSTC_HUMAN.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('MBHT_ECOLI.pdb',),
#  ('MBHT_ECOLI.pdb',),
#  ('BZP49_ARATH.pdb',),
#  ('BZP49_ARATH.pdb',),
#  ('BZP49_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('F4JYV3_ARATH.pdb',),
#  ('LRFN4_HUMAN.pdb',),
#  ('LRFN4_HUMAN.pdb',),
#  ('LRFN4_HUMAN.pdb',),
#  ('LRFN4_HUMAN.pdb',),
#  ('LRFN4_HUMAN.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('Y2899_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('C71BX_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('MDAR4_ARATH.pdb',),
#  ('IL23R_HUMAN.pdb',),
#  ('IL23R_HUMAN.pdb',),
#  ('IL23R_HUMAN.pdb',),
#  ('IL23R_HUMAN.pdb',),
#  ('IL23R_HUMAN.pdb',),
#  ('IL23R_HUMAN.pdb',),
#  ('PNSL4_ARATH.pdb',),
#  ('PNSL4_ARATH.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('NRT32_ARATH.pdb',),
#  ('NRT32_ARATH.pdb',),
#  ('NRT32_ARATH.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('CLM7_HUMAN.pdb',),
#  ('CLM7_HUMAN.pdb',),
#  ('CLM7_HUMAN.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('SEM4F_HUMAN.pdb',),
#  ('FIMP_HUMAN.pdb',),
#  ('FIMP_HUMAN.pdb',),
#  ('FIMP_HUMAN.pdb',),
#  ('FIMP_HUMAN.pdb',),
#  ('FIMP_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('NDUB8_HUMAN.pdb',),
#  ('NDUB8_HUMAN.pdb',),
#  ('NDUB8_HUMAN.pdb',),
#  ('NDUB8_HUMAN.pdb',),
#  ('NDUB8_HUMAN.pdb',),
#  ('NDUB8_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('LRAD1_HUMAN.pdb',),
#  ('UCRIL_HUMAN.pdb',),
#  ('UCRIL_HUMAN.pdb',),
#  ('VTI1B_HUMAN.pdb',),
#  ('VTI1B_HUMAN.pdb',),
#  ('VTI1B_HUMAN.pdb',),
#  ('VTI1B_HUMAN.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('Q54LU1_DICDI.pdb',),
#  ('S31D4_HUMAN.pdb',),
#  ('S31D4_HUMAN.pdb',),
#  ('S31D4_HUMAN.pdb',),
#  ('S31D4_HUMAN.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('Q869U2_DICDI.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('F4IF00_ARATH.pdb',),
#  ('YO199_YEAST.pdb',),
#  ('YO199_YEAST.pdb',),
#  ('YO199_YEAST.pdb',),
#  ('YO199_YEAST.pdb',),
#  ('HXK4_ARATH.pdb',),
#  ('HXK4_ARATH.pdb',),
#  ('HXK4_ARATH.pdb',),
#  ('HXK4_ARATH.pdb',),
#  ('TIM21_ARATH.pdb',),
#  ('TIM21_ARATH.pdb',),
#  ('TIM21_ARATH.pdb',),
#  ('ATL31_ARATH.pdb',),
#  ('ATL31_ARATH.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('SNORC_HUMAN.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('Y2923_ARATH.pdb',),
#  ('LRP12_HUMAN.pdb',),
#  ('LRP12_HUMAN.pdb',),
#  ('LRP12_HUMAN.pdb',),
#  ('LRP12_HUMAN.pdb',),
#  ('LRP12_HUMAN.pdb',),
#  ('Q869T4_DICDI.pdb',),
#  ('Q869T4_DICDI.pdb',),
#  ('Q869T4_DICDI.pdb',),
#  ('Q869T4_DICDI.pdb',),
#  ('Q869T4_DICDI.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('ATL13_ARATH.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('EREG_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('S31C1_HUMAN.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('CBP4_YEAST.pdb',),
#  ('CBP4_YEAST.pdb',),
#  ('CBP4_YEAST.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('MRX10_YEAST.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('VA721_ARATH.pdb',),
#  ('VA721_ARATH.pdb',),
#  ('VA721_ARATH.pdb',),
#  ('VA721_ARATH.pdb',),
#  ('VA721_ARATH.pdb',),
#  ('VA721_ARATH.pdb',),
#  ('MANEA_HUMAN.pdb',),
#  ('MANEA_HUMAN.pdb',),
#  ('MANEA_HUMAN.pdb',),
#  ('MANEA_HUMAN.pdb',),
#  ('MANEA_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('SIGL9_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('PLXA3_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('CD79B_HUMAN.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('GDT5_DICDI.pdb',),
#  ('GDT5_DICDI.pdb',),
#  ('GDT5_DICDI.pdb',),
#  ('GDT5_DICDI.pdb',),
#  ('Q940N3_ARATH.pdb',),
#  ('Q940N3_ARATH.pdb',),
#  ('Q940N3_ARATH.pdb',),
#  ('Q940N3_ARATH.pdb',),
#  ('Q940N3_ARATH.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('CD44_HUMAN.pdb',),
#  ('GLDH_ARATH.pdb',),
#  ('GLDH_ARATH.pdb',),
#  ('F4IB60_ARATH.pdb',),
#  ('F4IB60_ARATH.pdb',),
#  ('F4IB60_ARATH.pdb',),
#  ('F4IB60_ARATH.pdb',),
#  ('F4IB60_ARATH.pdb',),
#  ('F4IB60_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('RLP51_ARATH.pdb',),
#  ('SERP2_HUMAN.pdb',),
#  ('SERP2_HUMAN.pdb',),
#  ('SERP2_HUMAN.pdb',),
#  ('Y2027_ARATH.pdb',),
#  ('Y2027_ARATH.pdb',),
#  ('Y2027_ARATH.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('SLC31_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('CSMD1_HUMAN.pdb',),
#  ('Y7931_DICDI.pdb',),
#  ('Y7931_DICDI.pdb',),
#  ('Y7931_DICDI.pdb',),
#  ('Y7931_DICDI.pdb',),
#  ('DJLC_ECOLI.pdb',),
#  ('DJLC_ECOLI.pdb',),
#  ('DJLC_ECOLI.pdb',),
#  ('RN133_HUMAN.pdb',),
#  ('RN133_HUMAN.pdb',),
#  ('RN133_HUMAN.pdb',),
#  ('RN133_HUMAN.pdb',),
#  ('RN133_HUMAN.pdb',),
#  ('MNS1_ARATH.pdb',),
#  ('MNS1_ARATH.pdb',),
#  ('MNS1_ARATH.pdb',),
#  ('TOM22_YEAST.pdb',),
#  ('TOM22_YEAST.pdb',),
#  ('TOM22_YEAST.pdb',),
#  ('TOM22_YEAST.pdb',),
#  ('Y492_METJA.pdb',),
#  ('Y492_METJA.pdb',),
#  ('Y492_METJA.pdb',),
#  ('Y492_METJA.pdb',),
#  ('Y492_METJA.pdb',),
#  ('NKG2C_HUMAN.pdb',),
#  ('NKG2C_HUMAN.pdb',),
#  ('NKG2C_HUMAN.pdb',),
#  ('MGAT2_HUMAN.pdb',),
#  ('MGAT2_HUMAN.pdb',),
#  ('SC61B_DICDI.pdb',),
#  ('SC61B_DICDI.pdb',),
#  ('SC61B_DICDI.pdb',),
#  ('SC61B_DICDI.pdb',),
#  ('SC61B_DICDI.pdb',),
#  ('CLM5_HUMAN.pdb',),
#  ('CLM5_HUMAN.pdb',),
#  ('CLM5_HUMAN.pdb',),
#  ('CLM5_HUMAN.pdb',),
#  ('CLM5_HUMAN.pdb',),
#  ('CLM5_HUMAN.pdb',),
#  ('FTSH1_ARATH.pdb',),
#  ('FTSH1_ARATH.pdb',),
#  ('FTSH1_ARATH.pdb',),
#  ('FTSH1_ARATH.pdb',),
#  ('FTSH1_ARATH.pdb',),
#  ('FTSH1_ARATH.pdb',),
#  ('PCDA9_HUMAN.pdb',),
#  ('PCDA9_HUMAN.pdb',),
#  ('PCDA9_HUMAN.pdb',),
#  ('PCDA9_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('S31C2_HUMAN.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Y6044_DICDI.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('MNS1_ARATH.pdb',),
#  ('MNS1_ARATH.pdb',),
#  ('GGT7_HUMAN.pdb',),
#  ('GGT7_HUMAN.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('YO186_YEAST.pdb',),
#  ('GAUT6_ARATH.pdb',),
#  ('GAUT6_ARATH.pdb',),
#  ('GAUT6_ARATH.pdb',),
#  ('GAUT6_ARATH.pdb',),
#  ('GAUT6_ARATH.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('ERP5_YEAST.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('Q9ZV42_ARATH.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('NEP_HUMAN.pdb',),
#  ('CYF_ARATH.pdb',),
#  ('CYF_ARATH.pdb',),
#  ('CYF_ARATH.pdb',),
#  ('CYF_ARATH.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('Q54BE6_DICDI.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('TI236_ARATH.pdb',),
#  ('TI236_ARATH.pdb',),
#  ('TI236_ARATH.pdb',),
#  ('TIM54_YEAST.pdb',),
#  ('TIM54_YEAST.pdb',),
#  ('TIM54_YEAST.pdb',),
#  ('MUC21_HUMAN.pdb',),
#  ('MUC21_HUMAN.pdb',),
#  ('MUC21_HUMAN.pdb',),
#  ('MUC21_HUMAN.pdb',),
#  ('MUC21_HUMAN.pdb',),
#  ('MUC21_HUMAN.pdb',),
#  ('TNF12_HUMAN.pdb',),
#  ('TNF12_HUMAN.pdb',),
#  ('TNF12_HUMAN.pdb',),
#  ('TNF12_HUMAN.pdb',),
#  ('CLC4G_HUMAN.pdb',),
#  ('CLC4G_HUMAN.pdb',),
#  ('CLC4G_HUMAN.pdb',),
#  ('CLC4G_HUMAN.pdb',),
#  ('CLC4G_HUMAN.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('VPS62_YEAST.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('Q5EAF1_ARATH.pdb',),
#  ('SARAF_HUMAN.pdb',),
#  ('SARAF_HUMAN.pdb',),
#  ('SARAF_HUMAN.pdb',),
#  ('SARAF_HUMAN.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Q940H5_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('Y3475_ARATH.pdb',),
#  ('IL1AP_HUMAN.pdb',),
#  ('IL1AP_HUMAN.pdb',),
#  ('IL1AP_HUMAN.pdb',),
#  ('IL1AP_HUMAN.pdb',),
#  ('IL1AP_HUMAN.pdb',),
#  ('IL1AP_HUMAN.pdb',),
#  ('CASP_ARATH.pdb',),
#  ('CASP_ARATH.pdb',),
#  ('CASP_ARATH.pdb',),
#  ('CASP_ARATH.pdb',),
#  ('CASP_ARATH.pdb',),
#  ('TCMO_ARATH.pdb',),
#  ('TCMO_ARATH.pdb',),
#  ('TCMO_ARATH.pdb',),
#  ('TCMO_ARATH.pdb',),
#  ('XG113_ARATH.pdb',),
#  ('XG113_ARATH.pdb',),
#  ('XG113_ARATH.pdb',),
#  ('XG113_ARATH.pdb',),
#  ('XG113_ARATH.pdb',),
#  ('XG113_ARATH.pdb',),
#  ('B3GL1_HUMAN.pdb',),
#  ('B3GL1_HUMAN.pdb',),
#  ('B3GL1_HUMAN.pdb',),
#  ('B3GL1_HUMAN.pdb',),
#  ('B3GL1_HUMAN.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('GACV_DICDI.pdb',),
#  ('Q55DP5_DICDI.pdb',),
#  ('Q55DP5_DICDI.pdb',),
#  ('Q55DP5_DICDI.pdb',),
#  ('Q55DP5_DICDI.pdb',),
#  ('Q55DP5_DICDI.pdb',),
#  ('DIK1A_HUMAN.pdb',),
#  ('DIK1A_HUMAN.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('Y4245_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('WIT1_ARATH.pdb',),
#  ('Q54VY9_DICDI.pdb',),
#  ('Q54VY9_DICDI.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('ABD12_HUMAN.pdb',),
#  ('ABD12_HUMAN.pdb',),
#  ('ABD12_HUMAN.pdb',),
#  ('ABD12_HUMAN.pdb',),
#  ('ABD12_HUMAN.pdb',),
#  ('ABD12_HUMAN.pdb',),
#  ('RLK0_ARATH.pdb',),
#  ('RLK0_ARATH.pdb',),
#  ('RLK0_ARATH.pdb',),
#  ('RLK0_ARATH.pdb',),
#  ('RLK0_ARATH.pdb',),
#  ('RLK0_ARATH.pdb',),
#  ('ECEL1_HUMAN.pdb',),
#  ('ECEL1_HUMAN.pdb',),
#  ('ECEL1_HUMAN.pdb',),
#  ('ECEL1_HUMAN.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('Y1816_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('VA724_ARATH.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('LRFN1_HUMAN.pdb',),
#  ('MGAT2_HUMAN.pdb',),
#  ('MGAT2_HUMAN.pdb',),
#  ('MGAT2_HUMAN.pdb',),
#  ('MGAT2_HUMAN.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('Q54LS4_DICDI.pdb',),
#  ('P4H4_ARATH.pdb',),
#  ('P4H4_ARATH.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Q54PV3_DICDI.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('Y1755_ARATH.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('TMDD1_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('ANR46_HUMAN.pdb',),
#  ('ANR46_HUMAN.pdb',),
#  ('ANR46_HUMAN.pdb',),
#  ('ANR46_HUMAN.pdb',),
#  ('ANR46_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('GPX8_HUMAN.pdb',),
#  ('NRFF_ECOLI.pdb',),
#  ('NRFF_ECOLI.pdb',),
#  ('NRFF_ECOLI.pdb',),
#  ('NRFF_ECOLI.pdb',),
#  ('OFT37_ARATH.pdb',),
#  ('OFT37_ARATH.pdb',),
#  ('OFT37_ARATH.pdb',),
#  ('OFT37_ARATH.pdb',),
#  ('OFT37_ARATH.pdb',),
#  ('OFT37_ARATH.pdb',),
#  ('PLXB3_HUMAN.pdb',),
#  ('PLXB3_HUMAN.pdb',),
#  ('PLXB3_HUMAN.pdb',),
#  ('NPB15_HUMAN.pdb',),
#  ('NPB15_HUMAN.pdb',),
#  ('NPB15_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('MGT4B_HUMAN.pdb',),
#  ('DJLC_ECOLI.pdb',),
#  ('DJLC_ECOLI.pdb',),
#  ('ATL64_ARATH.pdb',),
#  ('ATL64_ARATH.pdb',),
#  ('ATL64_ARATH.pdb',),
#  ('ATL64_ARATH.pdb',),
#  ('ATL64_ARATH.pdb',),
#  ('ATL64_ARATH.pdb',),
#  ('ATL68_ARATH.pdb',),
#  ('ATL68_ARATH.pdb',),
#  ('ATL68_ARATH.pdb',),
#  ('ATL68_ARATH.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('ACBD5_HUMAN.pdb',),
#  ('IPIL1_HUMAN.pdb',),
#  ('IPIL1_HUMAN.pdb',),
#  ('IPIL1_HUMAN.pdb',),
#  ('IPIL1_HUMAN.pdb',),
#  ('IPIL1_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('GALT6_HUMAN.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('Q54GX9_DICDI.pdb',),
#  ('PSKR2_ARATH.pdb',),
#  ('PSKR2_ARATH.pdb',),
#  ('Y5129_ARATH.pdb',),
#  ('Y5129_ARATH.pdb',),
#  ('Y5129_ARATH.pdb',),
#  ('Y5129_ARATH.pdb',),
#  ('Y5129_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('TO203_ARATH.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('MGT4D_HUMAN.pdb',),
#  ('Y2559_ARATH.pdb',),
#  ('Y2559_ARATH.pdb',),
#  ('Y2559_ARATH.pdb',),
#  ('Y2559_ARATH.pdb',),
#  ('Y2559_ARATH.pdb',),
#  ('Q54Q41_DICDI.pdb',),
#  ('Q54Q41_DICDI.pdb',),
#  ('Q54Q41_DICDI.pdb',),
#  ('Q54Q41_DICDI.pdb',),
#  ('Q54Q41_DICDI.pdb',),
#  ('Q54Q41_DICDI.pdb',),
#  ('SLAF1_HUMAN.pdb',),
#  ('SLAF1_HUMAN.pdb',),
#  ('SLAF1_HUMAN.pdb',),
#  ('SLAF1_HUMAN.pdb',),
#  ('SLAF1_HUMAN.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('PETL_ARATH.pdb',),
#  ('GOLM2_HUMAN.pdb',),
#  ('GOLM2_HUMAN.pdb',),
#  ('GOLM2_HUMAN.pdb',),
#  ('GOLM2_HUMAN.pdb',),
#  ('HTRA2_HUMAN.pdb',),
#  ('HTRA2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMIG2_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('TMPS4_HUMAN.pdb',),
#  ('Y2921_ARATH.pdb',),
#  ('Y2921_ARATH.pdb',),
#  ('Y2921_ARATH.pdb',),
#  ('Y2921_ARATH.pdb',),
#  ('Y2921_ARATH.pdb',),
#  ('Y2921_ARATH.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('HUMMR_HUMAN.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('NDUA1_ARATH.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PHEX_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('PCDA2_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('RAE1E_HUMAN.pdb',),
#  ('Q9S790_ARATH.pdb',),
#  ('Q9S790_ARATH.pdb',),
#  ('Q9S790_ARATH.pdb',),
#  ('Q9S790_ARATH.pdb',),
#  ('Q9S790_ARATH.pdb',),
#  ('Q9S790_ARATH.pdb',),
#  ('GEMA_DICDI.pdb',),
#  ('GEMA_DICDI.pdb',),
#  ('GEMA_DICDI.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('BWNIN_HUMAN.pdb',),
#  ('LMTK3_HUMAN.pdb',),
#  ('LMTK3_HUMAN.pdb',),
#  ('LMTK3_HUMAN.pdb',),
#  ('LMTK3_HUMAN.pdb',),
#  ('LMTK3_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('NDUBB_HUMAN.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('YH213_YEAST.pdb',),
#  ('VTCN1_HUMAN.pdb',),
#  ('VTCN1_HUMAN.pdb',),
#  ('VTCN1_HUMAN.pdb',),
#  ('Q058J9_ARATH.pdb',),
#  ('Q058J9_ARATH.pdb',),
#  ('Q058J9_ARATH.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('SIA7E_HUMAN.pdb',),
#  ('ASPH_HUMAN.pdb',),
#  ('ASPH_HUMAN.pdb',),
#  ('ASPH_HUMAN.pdb',),
#  ('ASPH_HUMAN.pdb',),
#  ('ASPH_HUMAN.pdb',),
#  ('SINE3_ARATH.pdb',),
#  ('SINE3_ARATH.pdb',),
#  ('SINE3_ARATH.pdb',),
#  ('SINE3_ARATH.pdb',),
#  ('SINE3_ARATH.pdb',),
#  ('SINE3_ARATH.pdb',),
#  ('MIGA1_HUMAN.pdb',),
#  ('MIGA1_HUMAN.pdb',),
#  ('MIGA1_HUMAN.pdb',),
#  ('VTI12_ARATH.pdb',),
#  ('VTI12_ARATH.pdb',),
#  ...]

# %%
pd.concat([pd.DataFrame(actions_taken[i],columns=['position','amino_acid']) for i in actions_taken.keys()]).value_counts()
# Out:
# position  amino_acid
# 12        D             736
# 14        P             547
# 6         P             411
# 19        P             386
# 7         D             358
#                        ...
# 13        G               1
# 1         R               1
# 16        S               1
#           T               1
# 15        D               1
# Length: 63, dtype: int64

# %%
pd.DataFrame([actions_taken[i][-1] for i in actions_taken.keys()],columns=['position','amino_acid'])['amino_acid'].value_counts()
# Out:
# P    327
# D    115
# N     32
# K     12
# E      7
# H      3
# S      1
# Y      1
# W      1
# V      1
# Name: amino_acid, dtype: int64

# %%
for file in glob.glob('validation_structures/*.pdb'):
    if percentage_of_b(get_structural_annotations(file))>30:
        print(file,percentage_of_b(get_structural_annotations(file)))
# Out:
# validation_structures/1sb3_A_1_524_553_2024-01-09 19:57:28.pdb 33.33333333333333
# validation_structures/2ycz_A_1_75_104_2024-01-09 19:58:59.pdb 31.03448275862069
# validation_structures/RAE1E_HUMAN_2024-01-19 17:25:07.pdb 62.06896551724138
# validation_structures/4q65_A_1_452_481_2024-01-12 19:19:37.pdb 40.0
# validation_structures/2ash_C_1_320_349_2024-01-12 20:20:08.pdb 56.666666666666664
# validation_structures/CASP_ARATH_2024-01-19 17:12:09.pdb 41.37931034482759
# validation_structures/SINE3_ARATH_2024-01-19 17:41:17.pdb 31.03448275862069
# validation_structures/4c5u_A_1_321_350_2024-01-12 21:13:47.pdb 43.333333333333336
# validation_structures/CTSRD_HUMAN_2024-01-19 17:35:18.pdb 62.06896551724138
# validation_structures/NDUA1_ARATH_2024-01-19 17:16:19.pdb 31.03448275862069
# validation_structures/COX41_HUMAN_2024-01-19 17:26:27.pdb 37.93103448275862
# validation_structures/4xnj_A_1_449_478_2024-01-12 20:35:58.pdb 36.666666666666664
# validation_structures/STX1A_HUMAN_2024-01-19 17:02:35.pdb 31.03448275862069
# validation_structures/DIK1A_HUMAN_2024-01-19 17:37:36.pdb 34.48275862068966
# validation_structures/4c5u_A_1_321_350_2024-01-12 21:19:40.pdb 40.0
# validation_structures/NDUBB_HUMAN_2024-01-19 17:14:11.pdb 41.37931034482759
# validation_structures/4il6_D_1_108_137_2024-01-12 20:58:22.pdb 43.333333333333336
# validation_structures/4il6_D_1_108_137_2024-01-15 11:57:06.pdb 50.0
# validation_structures/4il6_D_1_108_137_2024-01-12 21:05:12.pdb 50.0
# validation_structures/NDUB8_HUMAN_2024-01-19 17:06:26.pdb 55.172413793103445
# validation_structures/4il6_D_1_108_137_2024-01-12 20:59:27.pdb 40.0
# validation_structures/OFT29_ARATH_2024-01-19 17:02:09.pdb 41.37931034482759
# validation_structures/4c5u_A_1_321_350_2024-01-09 19:49:33.pdb 44.827586206896555
# validation_structures/BZP49_ARATH_2024-01-19 17:18:50.pdb 31.03448275862069
# validation_structures/2onk_C_1_1_30_2024-01-12 20:37:04.pdb 36.666666666666664

# %%
with open(f'validation_results/{entropy}.pkl','wb') as file:
    pickle.dump(actions_taken,file)

# %%
given_entropies = ['0.01','0.001','0.0001','1e-05']

# %%
mutations_array_for_all_entropies = []

# %%
for entropy in given_entropies:
    saved_model_file_path = f'saved_models/saved_rl_model_1_lr_0.0007_gamma_0.95_ep_8000_entropic_factor_{entropy}_co_30.0_trained_on_tp_30_training.pth'
    loaded_estimator_each_entropy = PolicyNetwork(n_state, n_action, n_hidden, lr, entropy_weight=entropy)
    loaded_estimator_each_entropy.model.load_state_dict(torch.load(saved_model_file_path))
    total_reward_array,mean_validation_reward, standard_deviation,actions_taken, mutations_array = evaluate_model(estimator=loaded_estimator_each_entropy, env=env,num_episodes=500)
    with open(f'validation_results/{entropy}.pkl','wb') as file:
        pickle.dump(actions_taken,file)
    mutations_array_for_all_entropies.append([entropy,mutations_array])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [42:36<00:00,  5.11s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [41:05<00:00,  4.93s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [37:16<00:00,  4.47s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 500/500 [33:23<00:00,  4.01s/it]

# %%
def validate_entropy(entropy_file_path):
    saved_model_file_path = entropy_file_path
    entropy_base_path = os.path.basename(entropy_file_path).split('.')[0]
    loaded_estimator_each_entropy = PolicyNetwork(n_state, n_action, n_hidden, lr, entropy_weight=entropy)
    loaded_estimator_each_entropy.model.load_state_dict(torch.load(saved_model_file_path))
    total_reward_array,mean_validation_reward, standard_deviation,actions_taken, mutations_array = evaluate_model(estimator=loaded_estimator_each_entropy, env=env,num_episodes=500)
    with open(f'validation_results/{entropy_base_path}.pkl','wb') as file:
        pickle.dump(actions_taken,file)
    mutations_array_for_all_entropies.append([entropy,mutations_array])

# %%
mutations_array_for_all_entropies
with open('no_of_mutations_array_all_entropies.pkl', 'wb') as file:
    pickle.dump(mutations_array_for_all_entropies, file)

# %%
with open('delete.pkl', 'wb') as file:
    pickle.dump(actions_taken, file)

# %%
with open('no_of_mutations_array_all_entropies.pkl','rb') as file:
    loaded_dict = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6641/1977669442.py in <module>
#       1 with open('no_of_mutations_array_all_entropies.pkl','rb') as file:
# ----> 2     loaded_dict = pickle.load(file)
#
# NameError: name 'pickle' is not defined

# %%
loaded_dict
# Out:
# [['0.01',
#   [6,
#    5,
#    2,
#    8,
#    3,
#    9,
#    15,
#    8,
#    2,
#    6,
#    2,
#    5,
#    5,
#    7,
#    15,
#    6,
#    7,
#    5,
#    7,
#    5,
#    13,
#    3,
#    2,
#    4,
#    3,
#    2,
#    3,
#    15,
#    4,
#    5,
#    3,
#    7,
#    3,
#    7,
#    15,
#    3,
#    4,
#    11,
#    3,
#    4,
#    11,
#    15,
#    15,
#    6,
#    2,
#    15,
#    6,
#    15,
#    4,
#    7,
#    15,
#    5,
#    2,
#    2,
#    5,
#    11,
#    7,
#    5,
#    5,
#    9,
#    5,
#    5,
#    2,
#    2,
#    5,
#    2,
#    2,
#    9,
#    3,
#    5,
#    3,
#    15,
#    2,
#    4,
#    15,
#    15,
#    5,
#    15,
#    15,
#    15,
#    9,
#    3,
#    7,
#    3,
#    14,
#    15,
#    2,
#    15,
#    2,
#    2,
#    5,
#    4,
#    2,
#    3,
#    9,
#    2,
#    4,
#    15,
#    6,
#    2,
#    12,
#    8,
#    4,
#    2,
#    4,
#    2,
#    7,
#    6,
#    4,
#    2,
#    5,
#    5,
#    6,
#    15,
#    15,
#    7,
#    4,
#    15,
#    9,
#    6,
#    7,
#    15,
#    6,
#    5,
#    8,
#    6,
#    3,
#    4,
#    3,
#    4,
#    7,
#    15,
#    8,
#    5,
#    8,
#    6,
#    2,
#    2,
#    10,
#    3,
#    4,
#    7,
#    5,
#    3,
#    15,
#    7,
#    15,
#    7,
#    6,
#    6,
#    9,
#    15,
#    14,
#    6,
#    2,
#    5,
#    3,
#    15,
#    15,
#    6,
#    15,
#    4,
#    2,
#    2,
#    2,
#    7,
#    4,
#    8,
#    15,
#    3,
#    7,
#    7,
#    15,
#    3,
#    2,
#    15,
#    2,
#    3,
#    2,
#    7,
#    2,
#    6,
#    15,
#    8,
#    15,
#    3,
#    7,
#    9,
#    2,
#    4,
#    8,
#    15,
#    15,
#    5,
#    15,
#    2,
#    2,
#    12,
#    2,
#    2,
#    3,
#    4,
#    8,
#    4,
#    5,
#    4,
#    2,
#    5,
#    3,
#    4,
#    3,
#    7,
#    6,
#    15,
#    6,
#    9,
#    7,
#    4,
#    15,
#    3,
#    4,
#    8,
#    3,
#    3,
#    15,
#    10,
#    3,
#    13,
#    7,
#    15,
#    11,
#    6,
#    15,
#    4,
#    7,
#    13,
#    4,
#    4,
#    12,
#    8,
#    14,
#    9,
#    3,
#    2,
#    7,
#    4,
#    15,
#    15,
#    10,
#    5,
#    6,
#    2,
#    6,
#    15,
#    12,
#    15,
#    3,
#    2,
#    15,
#    8,
#    15,
#    3,
#    13,
#    3,
#    15,
#    14,
#    3,
#    4,
#    4,
#    5,
#    6,
#    7,
#    7,
#    7,
#    8,
#    7,
#    2,
#    12,
#    6,
#    15,
#    15,
#    5,
#    6,
#    5,
#    15,
#    5,
#    5,
#    6,
#    2,
#    4,
#    2,
#    15,
#    11,
#    3,
#    3,
#    6,
#    9,
#    3,
#    8,
#    5,
#    15,
#    6,
#    2,
#    5,
#    6,
#    5,
#    2,
#    5,
#    3,
#    2,
#    9,
#    10,
#    7,
#    2,
#    3,
#    10,
#    2,
#    2,
#    5,
#    11,
#    6,
#    3,
#    2,
#    3,
#    2,
#    4,
#    7,
#    14,
#    3,
#    3,
#    13,
#    4,
#    10,
#    15,
#    6,
#    9,
#    7,
#    4,
#    3,
#    3,
#    2,
#    14,
#    2,
#    4,
#    6,
#    3,
#    15,
#    15,
#    5,
#    7,
#    13,
#    15,
#    13,
#    15,
#    5,
#    4,
#    4,
#    5,
#    5,
#    15,
#    6,
#    3,
#    3,
#    5,
#    8,
#    2,
#    9,
#    5,
#    4,
#    15,
#    15,
#    12,
#    4,
#    8,
#    2,
#    3,
#    4,
#    15,
#    5,
#    3,
#    2,
#    2,
#    3,
#    3,
#    7,
#    11,
#    7,
#    4,
#    2,
#    15,
#    5,
#    4,
#    2,
#    2,
#    3,
#    3,
#    15,
#    2,
#    6,
#    7,
#    5,
#    2,
#    3,
#    14,
#    3,
#    15,
#    3,
#    6,
#    8,
#    2,
#    9,
#    2,
#    5,
#    4,
#    5,
#    3,
#    3,
#    3,
#    15,
#    6,
#    15,
#    3,
#    15,
#    5,
#    5,
#    6,
#    15,
#    7,
#    6,
#    15,
#    2,
#    2,
#    9,
#    3,
#    2,
#    10,
#    4,
#    3,
#    2,
#    6,
#    7,
#    2,
#    2,
#    7,
#    15,
#    3,
#    2,
#    4,
#    2,
#    2,
#    3,
#    3,
#    8,
#    6,
#    3,
#    5,
#    15,
#    2,
#    15,
#    4,
#    15,
#    2,
#    10,
#    4,
#    7,
#    3,
#    7,
#    2,
#    9,
#    8,
#    14,
#    15,
#    15,
#    15,
#    3,
#    2,
#    15,
#    4,
#    15,
#    15,
#    2,
#    4,
#    3,
#    11,
#    3,
#    9,
#    9,
#    5,
#    12,
#    4,
#    2,
#    15,
#    6,
#    9,
#    3,
#    5,
#    3,
#    3,
#    11,
#    2]],
#  ['0.001',
#   [3,
#    6,
#    2,
#    4,
#    2,
#    9,
#    2,
#    11,
#    2,
#    4,
#    2,
#    6,
#    15,
#    6,
#    2,
#    7,
#    9,
#    4,
#    7,
#    8,
#    6,
#    6,
#    3,
#    2,
#    7,
#    5,
#    6,
#    14,
#    15,
#    10,
#    7,
#    4,
#    4,
#    6,
#    6,
#    12,
#    2,
#    2,
#    3,
#    4,
#    6,
#    2,
#    4,
#    4,
#    4,
#    15,
#    15,
#    5,
#    15,
#    9,
#    2,
#    3,
#    4,
#    8,
#    7,
#    3,
#    2,
#    15,
#    15,
#    8,
#    2,
#    2,
#    11,
#    10,
#    2,
#    15,
#    6,
#    9,
#    9,
#    5,
#    9,
#    4,
#    2,
#    8,
#    7,
#    2,
#    6,
#    11,
#    11,
#    10,
#    10,
#    5,
#    2,
#    6,
#    15,
#    6,
#    5,
#    2,
#    3,
#    15,
#    9,
#    2,
#    15,
#    4,
#    5,
#    15,
#    2,
#    2,
#    15,
#    6,
#    4,
#    8,
#    15,
#    7,
#    2,
#    11,
#    2,
#    6,
#    2,
#    6,
#    15,
#    4,
#    2,
#    10,
#    15,
#    2,
#    15,
#    7,
#    5,
#    15,
#    7,
#    3,
#    2,
#    4,
#    5,
#    7,
#    11,
#    3,
#    15,
#    15,
#    2,
#    5,
#    8,
#    3,
#    2,
#    2,
#    2,
#    8,
#    2,
#    3,
#    3,
#    6,
#    15,
#    6,
#    4,
#    7,
#    3,
#    15,
#    2,
#    9,
#    15,
#    6,
#    3,
#    12,
#    15,
#    7,
#    6,
#    3,
#    3,
#    15,
#    8,
#    2,
#    15,
#    6,
#    10,
#    2,
#    8,
#    12,
#    3,
#    7,
#    6,
#    11,
#    5,
#    6,
#    4,
#    10,
#    2,
#    5,
#    5,
#    4,
#    8,
#    6,
#    6,
#    3,
#    3,
#    11,
#    10,
#    6,
#    15,
#    15,
#    4,
#    4,
#    4,
#    4,
#    5,
#    7,
#    8,
#    2,
#    6,
#    6,
#    8,
#    4,
#    4,
#    3,
#    2,
#    4,
#    2,
#    4,
#    3,
#    4,
#    2,
#    6,
#    15,
#    11,
#    13,
#    2,
#    5,
#    2,
#    3,
#    7,
#    3,
#    8,
#    11,
#    12,
#    7,
#    8,
#    8,
#    14,
#    6,
#    15,
#    3,
#    2,
#    3,
#    2,
#    2,
#    8,
#    2,
#    15,
#    4,
#    15,
#    2,
#    2,
#    4,
#    2,
#    2,
#    8,
#    15,
#    2,
#    3,
#    5,
#    7,
#    4,
#    7,
#    2,
#    3,
#    5,
#    7,
#    3,
#    15,
#    2,
#    2,
#    4,
#    7,
#    7,
#    5,
#    2,
#    6,
#    3,
#    9,
#    10,
#    15,
#    4,
#    10,
#    3,
#    7,
#    2,
#    5,
#    2,
#    14,
#    5,
#    5,
#    5,
#    3,
#    10,
#    3,
#    3,
#    8,
#    9,
#    2,
#    2,
#    3,
#    6,
#    3,
#    2,
#    5,
#    11,
#    7,
#    2,
#    3,
#    8,
#    7,
#    12,
#    7,
#    12,
#    6,
#    5,
#    7,
#    12,
#    5,
#    14,
#    4,
#    5,
#    9,
#    6,
#    4,
#    4,
#    8,
#    6,
#    15,
#    6,
#    8,
#    8,
#    2,
#    5,
#    2,
#    2,
#    5,
#    7,
#    7,
#    3,
#    2,
#    4,
#    15,
#    6,
#    2,
#    14,
#    3,
#    14,
#    4,
#    2,
#    2,
#    6,
#    4,
#    2,
#    7,
#    7,
#    7,
#    15,
#    5,
#    3,
#    4,
#    3,
#    4,
#    5,
#    2,
#    3,
#    7,
#    7,
#    15,
#    12,
#    2,
#    5,
#    7,
#    2,
#    3,
#    7,
#    7,
#    2,
#    3,
#    5,
#    9,
#    15,
#    12,
#    12,
#    9,
#    11,
#    2,
#    2,
#    7,
#    8,
#    5,
#    6,
#    4,
#    3,
#    5,
#    10,
#    6,
#    8,
#    6,
#    11,
#    4,
#    3,
#    14,
#    6,
#    9,
#    8,
#    2,
#    10,
#    4,
#    11,
#    9,
#    4,
#    2,
#    4,
#    2,
#    11,
#    3,
#    10,
#    2,
#    8,
#    7,
#    11,
#    15,
#    8,
#    3,
#    8,
#    9,
#    4,
#    7,
#    10,
#    14,
#    15,
#    5,
#    12,
#    2,
#    5,
#    6,
#    5,
#    3,
#    8,
#    5,
#    5,
#    5,
#    8,
#    7,
#    5,
#    13,
#    15,
#    15,
#    5,
#    2,
#    2,
#    9,
#    8,
#    5,
#    9,
#    3,
#    10,
#    13,
#    4,
#    2,
#    15,
#    2,
#    4,
#    12,
#    11,
#    4,
#    8,
#    10,
#    6,
#    4,
#    3,
#    2,
#    8,
#    5,
#    2,
#    3,
#    4,
#    2,
#    9,
#    15,
#    3,
#    3,
#    4,
#    4,
#    15,
#    5,
#    15,
#    15,
#    3,
#    4,
#    4,
#    3,
#    2,
#    13,
#    6,
#    5,
#    8,
#    10,
#    2,
#    7,
#    8,
#    6,
#    14,
#    7,
#    6,
#    10,
#    10,
#    4,
#    8]],
#  ['0.0001',
#   [12,
#    5,
#    5,
#    2,
#    4,
#    7,
#    2,
#    2,
#    8,
#    6,
#    4,
#    5,
#    15,
#    3,
#    15,
#    8,
#    9,
#    8,
#    2,
#    6,
#    14,
#    2,
#    4,
#    3,
#    4,
#    2,
#    2,
#    3,
#    4,
#    7,
#    15,
#    3,
#    9,
#    2,
#    8,
#    4,
#    4,
#    3,
#    2,
#    7,
#    8,
#    4,
#    2,
#    5,
#    2,
#    3,
#    2,
#    4,
#    3,
#    4,
#    3,
#    7,
#    3,
#    5,
#    9,
#    2,
#    2,
#    5,
#    3,
#    5,
#    5,
#    2,
#    5,
#    10,
#    7,
#    8,
#    3,
#    7,
#    8,
#    11,
#    15,
#    8,
#    4,
#    2,
#    5,
#    4,
#    11,
#    7,
#    7,
#    4,
#    2,
#    2,
#    3,
#    12,
#    15,
#    5,
#    4,
#    2,
#    4,
#    5,
#    7,
#    15,
#    8,
#    3,
#    4,
#    4,
#    5,
#    2,
#    8,
#    2,
#    3,
#    6,
#    7,
#    2,
#    6,
#    3,
#    2,
#    3,
#    11,
#    3,
#    3,
#    11,
#    6,
#    6,
#    2,
#    10,
#    11,
#    2,
#    6,
#    6,
#    6,
#    6,
#    3,
#    2,
#    4,
#    3,
#    3,
#    9,
#    3,
#    5,
#    8,
#    9,
#    2,
#    4,
#    4,
#    3,
#    6,
#    4,
#    2,
#    4,
#    15,
#    5,
#    4,
#    7,
#    3,
#    2,
#    5,
#    15,
#    12,
#    8,
#    13,
#    2,
#    2,
#    14,
#    3,
#    11,
#    2,
#    15,
#    6,
#    3,
#    5,
#    9,
#    7,
#    4,
#    12,
#    3,
#    2,
#    2,
#    3,
#    5,
#    2,
#    2,
#    8,
#    12,
#    2,
#    4,
#    5,
#    13,
#    15,
#    2,
#    6,
#    14,
#    15,
#    3,
#    15,
#    5,
#    2,
#    7,
#    4,
#    2,
#    4,
#    2,
#    9,
#    3,
#    11,
#    7,
#    8,
#    8,
#    10,
#    15,
#    6,
#    15,
#    3,
#    12,
#    3,
#    10,
#    6,
#    6,
#    3,
#    3,
#    10,
#    2,
#    8,
#    3,
#    7,
#    8,
#    2,
#    8,
#    6,
#    2,
#    3,
#    2,
#    9,
#    15,
#    14,
#    2,
#    2,
#    4,
#    8,
#    2,
#    5,
#    2,
#    4,
#    4,
#    2,
#    3,
#    8,
#    2,
#    4,
#    6,
#    3,
#    4,
#    8,
#    4,
#    13,
#    2,
#    13,
#    6,
#    11,
#    2,
#    4,
#    5,
#    2,
#    3,
#    7,
#    3,
#    3,
#    15,
#    4,
#    3,
#    4,
#    15,
#    2,
#    11,
#    3,
#    5,
#    3,
#    3,
#    4,
#    5,
#    10,
#    6,
#    5,
#    10,
#    13,
#    2,
#    7,
#    6,
#    3,
#    4,
#    8,
#    6,
#    5,
#    3,
#    3,
#    8,
#    3,
#    2,
#    2,
#    3,
#    11,
#    11,
#    6,
#    6,
#    8,
#    8,
#    15,
#    15,
#    14,
#    9,
#    4,
#    4,
#    6,
#    7,
#    6,
#    2,
#    4,
#    5,
#    7,
#    2,
#    2,
#    4,
#    2,
#    6,
#    3,
#    15,
#    4,
#    2,
#    4,
#    6,
#    3,
#    5,
#    2,
#    12,
#    4,
#    15,
#    6,
#    2,
#    6,
#    8,
#    5,
#    4,
#    11,
#    2,
#    4,
#    8,
#    8,
#    7,
#    15,
#    15,
#    2,
#    3,
#    7,
#    2,
#    6,
#    2,
#    9,
#    6,
#    3,
#    15,
#    2,
#    3,
#    4,
#    5,
#    4,
#    6,
#    8,
#    8,
#    8,
#    3,
#    8,
#    10,
#    2,
#    7,
#    2,
#    6,
#    4,
#    8,
#    15,
#    15,
#    4,
#    3,
#    2,
#    4,
#    2,
#    2,
#    5,
#    9,
#    3,
#    7,
#    3,
#    8,
#    2,
#    2,
#    6,
#    6,
#    3,
#    2,
#    2,
#    3,
#    3,
#    3,
#    5,
#    5,
#    5,
#    15,
#    7,
#    6,
#    2,
#    11,
#    6,
#    4,
#    6,
#    15,
#    15,
#    3,
#    7,
#    3,
#    12,
#    2,
#    2,
#    15,
#    3,
#    2,
#    2,
#    6,
#    10,
#    5,
#    11,
#    4,
#    2,
#    9,
#    2,
#    4,
#    5,
#    2,
#    15,
#    2,
#    10,
#    7,
#    15,
#    3,
#    3,
#    8,
#    3,
#    8,
#    15,
#    3,
#    10,
#    5,
#    9,
#    4,
#    8,
#    2,
#    11,
#    4,
#    8,
#    4,
#    7,
#    5,
#    4,
#    6,
#    5,
#    5,
#    2,
#    10,
#    2,
#    2,
#    2,
#    5,
#    2,
#    3,
#    4,
#    11,
#    2,
#    6,
#    15,
#    3,
#    3,
#    12,
#    9,
#    10,
#    3,
#    2,
#    6,
#    12,
#    5,
#    8,
#    6,
#    15,
#    4,
#    2,
#    5,
#    5,
#    6,
#    10,
#    2,
#    3,
#    3,
#    5,
#    5,
#    6,
#    2,
#    3,
#    5,
#    4,
#    2,
#    4,
#    3,
#    4]],
#  ['1e-05',
#   [3,
#    6,
#    5,
#    5,
#    8,
#    7,
#    2,
#    10,
#    3,
#    4,
#    5,
#    3,
#    7,
#    3,
#    6,
#    3,
#    3,
#    10,
#    4,
#    5,
#    3,
#    4,
#    2,
#    4,
#    8,
#    6,
#    3,
#    11,
#    5,
#    2,
#    3,
#    3,
#    6,
#    4,
#    3,
#    2,
#    3,
#    12,
#    2,
#    2,
#    4,
#    6,
#    6,
#    2,
#    7,
#    10,
#    8,
#    3,
#    2,
#    10,
#    2,
#    15,
#    2,
#    3,
#    2,
#    2,
#    5,
#    11,
#    6,
#    3,
#    3,
#    2,
#    4,
#    10,
#    3,
#    3,
#    5,
#    4,
#    13,
#    5,
#    3,
#    7,
#    2,
#    3,
#    4,
#    2,
#    2,
#    3,
#    5,
#    5,
#    9,
#    2,
#    2,
#    9,
#    5,
#    11,
#    15,
#    8,
#    3,
#    2,
#    4,
#    2,
#    3,
#    11,
#    8,
#    3,
#    3,
#    11,
#    4,
#    2,
#    3,
#    3,
#    4,
#    4,
#    2,
#    8,
#    3,
#    11,
#    4,
#    7,
#    2,
#    5,
#    2,
#    3,
#    5,
#    15,
#    8,
#    2,
#    5,
#    2,
#    4,
#    3,
#    5,
#    2,
#    2,
#    6,
#    3,
#    4,
#    2,
#    15,
#    6,
#    2,
#    7,
#    8,
#    4,
#    9,
#    2,
#    6,
#    5,
#    3,
#    3,
#    5,
#    8,
#    10,
#    6,
#    3,
#    2,
#    2,
#    5,
#    4,
#    8,
#    4,
#    3,
#    2,
#    3,
#    3,
#    4,
#    4,
#    6,
#    4,
#    5,
#    2,
#    4,
#    15,
#    6,
#    5,
#    4,
#    14,
#    4,
#    3,
#    2,
#    2,
#    4,
#    2,
#    4,
#    2,
#    14,
#    2,
#    3,
#    4,
#    3,
#    2,
#    9,
#    2,
#    2,
#    3,
#    10,
#    8,
#    15,
#    6,
#    15,
#    5,
#    5,
#    3,
#    4,
#    6,
#    15,
#    15,
#    2,
#    8,
#    5,
#    15,
#    7,
#    4,
#    3,
#    6,
#    3,
#    3,
#    2,
#    2,
#    2,
#    6,
#    2,
#    2,
#    5,
#    2,
#    2,
#    2,
#    11,
#    2,
#    8,
#    6,
#    4,
#    3,
#    7,
#    2,
#    7,
#    7,
#    4,
#    6,
#    8,
#    4,
#    12,
#    4,
#    5,
#    8,
#    7,
#    2,
#    2,
#    3,
#    5,
#    2,
#    3,
#    2,
#    4,
#    10,
#    9,
#    14,
#    2,
#    5,
#    4,
#    4,
#    4,
#    8,
#    7,
#    9,
#    2,
#    3,
#    6,
#    2,
#    2,
#    7,
#    6,
#    5,
#    7,
#    7,
#    15,
#    11,
#    4,
#    4,
#    2,
#    8,
#    3,
#    2,
#    5,
#    6,
#    11,
#    9,
#    11,
#    5,
#    9,
#    4,
#    6,
#    14,
#    2,
#    5,
#    2,
#    2,
#    15,
#    5,
#    2,
#    10,
#    7,
#    5,
#    6,
#    12,
#    5,
#    7,
#    13,
#    3,
#    4,
#    12,
#    6,
#    3,
#    5,
#    2,
#    9,
#    5,
#    3,
#    11,
#    6,
#    3,
#    4,
#    2,
#    4,
#    12,
#    9,
#    2,
#    4,
#    3,
#    3,
#    2,
#    3,
#    4,
#    4,
#    5,
#    9,
#    5,
#    5,
#    3,
#    6,
#    3,
#    4,
#    3,
#    5,
#    2,
#    7,
#    6,
#    2,
#    5,
#    4,
#    5,
#    8,
#    9,
#    10,
#    3,
#    7,
#    4,
#    10,
#    5,
#    3,
#    2,
#    4,
#    9,
#    6,
#    3,
#    3,
#    12,
#    4,
#    2,
#    15,
#    2,
#    3,
#    5,
#    7,
#    2,
#    4,
#    5,
#    9,
#    3,
#    8,
#    7,
#    3,
#    5,
#    7,
#    9,
#    2,
#    10,
#    3,
#    3,
#    3,
#    6,
#    2,
#    4,
#    4,
#    2,
#    8,
#    9,
#    6,
#    2,
#    2,
#    15,
#    13,
#    3,
#    9,
#    2,
#    2,
#    8,
#    9,
#    2,
#    2,
#    9,
#    9,
#    15,
#    2,
#    4,
#    3,
#    2,
#    2,
#    4,
#    7,
#    7,
#    3,
#    3,
#    2,
#    2,
#    7,
#    15,
#    2,
#    6,
#    4,
#    4,
#    7,
#    11,
#    3,
#    7,
#    4,
#    3,
#    2,
#    8,
#    2,
#    4,
#    2,
#    2,
#    4,
#    2,
#    2,
#    5,
#    5,
#    6,
#    15,
#    4,
#    3,
#    2,
#    5,
#    10,
#    10,
#    4,
#    5,
#    9,
#    11,
#    5,
#    4,
#    9,
#    5,
#    12,
#    5,
#    4,
#    10,
#    4,
#    8,
#    2,
#    4,
#    3,
#    5,
#    15,
#    3,
#    4,
#    4,
#    9,
#    4,
#    3,
#    2,
#    3,
#    3,
#    5,
#    4,
#    8,
#    5,
#    2,
#    4,
#    9,
#    4,
#    5,
#    10,
#    5,
#    4,
#    5,
#    5,
#    10,
#    2,
#    2,
#    3,
#    2,
#    4,
#    2,
#    2,
#    4,
#    2,
#    3]]]

# %%
actions_taken
# Out:
# {0: [[18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [24, 'F'],
#   [25, 'P']],
#  1: [[25, 'P'], [10, 'P']],
#  2: [[12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'D'],
#   [22, 'T'],
#   [10, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  3: [[23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P']],
#  4: [[10, 'P'], [18, 'D'], [25, 'P']],
#  5: [[10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [25, 'P']],
#  6: [[25, 'P'], [11, 'M'], [12, 'P'], [18, 'D'], [10, 'P']],
#  7: [[12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P']],
#  8: [[25, 'P'], [18, 'D'], [18, 'D'], [10, 'P']],
#  9: [[12, 'P'], [23, 'P']],
#  10: [[18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P']],
#  11: [[10, 'P'], [23, 'P']],
#  12: [[23, 'P'], [23, 'P'], [12, 'P']],
#  13: [[10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [22, 'T']],
#  14: [[22, 'T'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  15: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D']],
#  16: [[23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  17: [[10, 'P'], [12, 'P'], [18, 'D'], [12, 'P'], [26, 'P'], [25, 'P']],
#  18: [[25, 'P'], [23, 'P'], [10, 'P']],
#  19: [[10, 'P'], [23, 'P'], [18, 'D']],
#  20: [[10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  21: [[18, 'D'], [23, 'P'], [18, 'D'], [23, 'P'], [12, 'P'], [10, 'P']],
#  22: [[12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  23: [[10, 'P'], [12, 'P'], [18, 'D'], [12, 'P'], [23, 'P']],
#  24: [[10, 'P'], [18, 'D'], [25, 'P']],
#  25: [[29, 'L'], [10, 'P'], [25, 'P'], [25, 'P'], [25, 'P'], [18, 'D']],
#  26: [[12, 'P'], [18, 'D'], [10, 'P'], [23, 'P']],
#  27: [[26, 'P'], [25, 'P'], [10, 'P'], [23, 'P']],
#  28: [[18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [1, 'Y']],
#  29: [[23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D']],
#  30: [[18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D']],
#  31: [[12, 'P'], [10, 'P'], [23, 'P'], [26, 'P']],
#  32: [[25, 'P'], [10, 'P'], [12, 'P'], [10, 'P'], [12, 'P'], [18, 'D']],
#  33: [[10, 'P'], [25, 'P'], [25, 'P'], [10, 'P'], [18, 'D'], [23, 'P']],
#  34: [[18, 'D'], [12, 'P'], [23, 'P']],
#  35: [[12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P']],
#  36: [[10, 'P'], [23, 'P']],
#  37: [[21, 'D'], [18, 'D'], [10, 'P']],
#  38: [[18, 'D'], [25, 'P'], [18, 'D'], [10, 'P']],
#  39: [[12, 'P'], [12, 'P'], [12, 'P'], [10, 'P']],
#  40: [[18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [22, 'T'],
#   [18, 'D']],
#  41: [[18, 'D'], [18, 'D'], [12, 'P']],
#  42: [[23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P']],
#  43: [[12, 'P'], [10, 'P'], [10, 'P'], [23, 'P']],
#  44: [[10, 'P'], [18, 'D'], [25, 'P'], [23, 'P']],
#  45: [[25, 'P'], [25, 'P'], [23, 'P'], [23, 'P'], [25, 'P'], [12, 'P']],
#  46: [[23, 'P'], [23, 'P'], [12, 'P'], [18, 'D']],
#  47: [[10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [20, 'G'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  48: [[10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D']],
#  49: [[18, 'D'], [10, 'P'], [10, 'P'], [10, 'P'], [12, 'P'], [25, 'P']],
#  50: [[12, 'P'], [25, 'P']],
#  51: [[12, 'P'], [10, 'P'], [25, 'P']],
#  52: [[12, 'P'], [12, 'P'], [18, 'D']],
#  53: [[25, 'P'], [12, 'P'], [12, 'P'], [12, 'P'], [23, 'P']],
#  54: [[25, 'P'], [10, 'P']],
#  55: [[18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [7, 'P'],
#   [12, 'P']],
#  56: [[18, 'D'], [23, 'P']],
#  57: [[25, 'P'], [18, 'D'], [12, 'P']],
#  58: [[23, 'P'], [18, 'D'], [10, 'P']],
#  59: [[12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [13, 'G'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  60: [[18, 'D'], [10, 'P'], [22, 'T'], [12, 'P'], [12, 'P'], [25, 'P']],
#  61: [[10, 'P'], [18, 'D'], [12, 'P'], [23, 'P']],
#  62: [[23, 'P'], [10, 'P'], [18, 'D']],
#  63: [[18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P']],
#  64: [[10, 'P'], [10, 'P'], [10, 'P'], [10, 'P'], [23, 'P']],
#  65: [[12, 'P'], [12, 'P'], [23, 'P']],
#  66: [[12, 'P'], [25, 'P'], [23, 'P']],
#  67: [[10, 'P'], [10, 'P'], [12, 'P'], [25, 'P']],
#  68: [[10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [26, 'P']],
#  69: [[18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [0, 'N'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [13, 'G']],
#  70: [[25, 'P'], [12, 'P']],
#  71: [[23, 'P'], [12, 'P'], [10, 'P'], [23, 'P'], [12, 'P'], [18, 'D']],
#  72: [[18, 'D'], [25, 'P']],
#  73: [[10, 'P'], [12, 'P']],
#  74: [[18, 'D'], [18, 'D']],
#  75: [[23, 'P'], [12, 'P'], [18, 'D'], [12, 'P'], [10, 'P']],
#  76: [[10, 'P'], [23, 'P']],
#  77: [[23, 'P'], [18, 'D'], [25, 'P'], [23, 'P'], [10, 'P']],
#  78: [[12, 'P'], [18, 'D']],
#  79: [[22, 'T'], [18, 'D'], [10, 'P'], [10, 'P'], [12, 'P']],
#  80: [[10, 'P'], [25, 'P'], [12, 'P']],
#  81: [[10, 'P'], [18, 'D'], [25, 'P'], [25, 'P'], [23, 'P'], [26, 'P']],
#  82: [[23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D']],
#  83: [[12, 'P'], [18, 'D'], [12, 'P'], [23, 'P']],
#  84: [[18, 'D'], [13, 'H']],
#  85: [[23, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [11, 'Y'],
#   [12, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [23, 'P'],
#   [12, 'P']],
#  86: [[26, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [25, 'P'],
#   [10, 'P']],
#  87: [[10, 'P'], [25, 'P'], [18, 'D']],
#  88: [[23, 'P'], [12, 'P'], [10, 'P'], [12, 'P'], [23, 'P'], [18, 'D']],
#  89: [[12, 'P'], [23, 'P']],
#  90: [[10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  91: [[23, 'P'], [10, 'P']],
#  92: [[12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  93: [[23, 'P'], [25, 'P'], [10, 'P'], [23, 'P'], [22, 'T']],
#  94: [[10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P']],
#  95: [[25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [22, 'T'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P']],
#  96: [[18, 'D'], [12, 'P'], [12, 'P'], [10, 'P'], [18, 'D'], [25, 'P']],
#  97: [[18, 'D'], [10, 'P'], [12, 'P'], [12, 'P'], [18, 'D'], [23, 'P']],
#  98: [[18, 'D'], [23, 'P']],
#  99: [[26, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P']],
#  100: [[23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [18, 'D'],
#   [27, 'V'],
#   [25, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [27, 'V'],
#   [23, 'P']],
#  101: [[23, 'P'], [10, 'P']],
#  102: [[25, 'P'], [18, 'D'], [10, 'P']],
#  103: [[23, 'P'], [18, 'D'], [11, 'Y'], [12, 'P'], [23, 'P'], [10, 'P']],
#  104: [[10, 'P'], [23, 'P']],
#  105: [[10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P']],
#  106: [[12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [27, 'V'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  107: [[12, 'P'], [23, 'P'], [25, 'P']],
#  108: [[10, 'P'], [12, 'P'], [23, 'P'], [10, 'P'], [25, 'P']],
#  109: [[25, 'P'], [10, 'P'], [10, 'P'], [12, 'P'], [18, 'D']],
#  110: [[10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  111: [[12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  112: [[10, 'P'], [23, 'P'], [18, 'D'], [23, 'P'], [12, 'P']],
#  113: [[12, 'P'], [18, 'D']],
#  114: [[25, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  115: [[23, 'P'], [25, 'P']],
#  116: [[18, 'E'], [12, 'P'], [10, 'P'], [12, 'P'], [25, 'P']],
#  117: [[18, 'D'], [10, 'P'], [12, 'P']],
#  118: [[18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [20, 'G']],
#  119: [[23, 'P'], [18, 'D'], [18, 'D'], [12, 'P']],
#  120: [[13, 'G'], [18, 'D']],
#  121: [[10, 'P'], [12, 'P']],
#  122: [[23, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P']],
#  123: [[10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  124: [[25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  125: [[10, 'P'], [10, 'P'], [12, 'P'], [22, 'T']],
#  126: [[10, 'P'], [10, 'P'], [25, 'P']],
#  127: [[10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [22, 'T'],
#   [10, 'P'],
#   [18, 'D']],
#  128: [[18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [22, 'T'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P']],
#  129: [[10, 'P'], [10, 'P'], [18, 'D'], [25, 'P']],
#  130: [[10, 'P'], [12, 'P']],
#  131: [[12, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  132: [[10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P']],
#  133: [[25, 'P'],
#   [26, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  134: [[18, 'F'], [25, 'P'], [10, 'P'], [12, 'P'], [23, 'P'], [18, 'D']],
#  135: [[25, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  136: [[12, 'P'], [23, 'P']],
#  137: [[12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P']],
#  138: [[10, 'P'], [12, 'P']],
#  139: [[23, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  140: [[18, 'D'], [10, 'P'], [25, 'P'], [10, 'P'], [23, 'P']],
#  141: [[25, 'P'], [12, 'P'], [25, 'P'], [25, 'P'], [25, 'P'], [10, 'P']],
#  142: [[10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [22, 'T'],
#   [10, 'P'],
#   [26, 'P'],
#   [12, 'P']],
#  143: [[23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  144: [[23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P']],
#  145: [[10, 'P'], [10, 'P'], [23, 'P'], [26, 'P'], [23, 'P'], [18, 'D']],
#  146: [[23, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [26, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P']],
#  147: [[23, 'P'], [25, 'P'], [23, 'P'], [10, 'P'], [18, 'D']],
#  148: [[12, 'P'], [26, 'P']],
#  149: [[26, 'P'], [10, 'P'], [23, 'P'], [25, 'P'], [12, 'P']],
#  150: [[18, 'D'], [12, 'P'], [23, 'P']],
#  151: [[25, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [25, 'P']],
#  152: [[23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [22, 'T'],
#   [25, 'P']],
#  153: [[18, 'D'], [23, 'P'], [18, 'P'], [23, 'P'], [10, 'P']],
#  154: [[10, 'P'], [25, 'P'], [25, 'P'], [13, 'G']],
#  155: [[12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [13, 'G'],
#   [12, 'G'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  156: [[25, 'P'], [12, 'P']],
#  157: [[25, 'P'], [18, 'D']],
#  158: [[12, 'P'], [23, 'P'], [12, 'P'], [10, 'P']],
#  159: [[10, 'P'], [18, 'D'], [18, 'D'], [10, 'P'], [25, 'P']],
#  160: [[12, 'P'], [23, 'P']],
#  161: [[10, 'P'], [18, 'D']],
#  162: [[23, 'P'], [12, 'P'], [10, 'P'], [12, 'P'], [18, 'D']],
#  163: [[12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [26, 'P']],
#  164: [[10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D']],
#  165: [[26, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  166: [[18, 'D'], [10, 'P']],
#  167: [[10, 'P'], [18, 'D'], [25, 'P'], [23, 'P']],
#  168: [[10, 'P'], [18, 'D']],
#  169: [[10, 'P'], [22, 'T'], [10, 'P'], [10, 'P'], [12, 'P'], [23, 'P']],
#  170: [[18, 'D'], [25, 'P'], [23, 'P'], [12, 'P']],
#  171: [[10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [18, 'D']],
#  172: [[25, 'P'], [10, 'P']],
#  173: [[22, 'T'], [18, 'D'], [10, 'P'], [10, 'P'], [10, 'P'], [25, 'P']],
#  174: [[12, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  175: [[12, 'P'], [18, 'D'], [29, 'V'], [25, 'P'], [10, 'P']],
#  176: [[23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P']],
#  177: [[18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [24, 'F'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P']],
#  178: [[23, 'P'], [12, 'P'], [23, 'P'], [12, 'P'], [10, 'P']],
#  179: [[26, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P']],
#  180: [[10, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  181: [[12, 'P'], [23, 'P'], [12, 'P'], [25, 'P'], [25, 'P'], [18, 'D']],
#  182: [[10, 'P'], [18, 'D'], [18, 'D'], [10, 'P'], [23, 'P']],
#  183: [[10, 'P'], [10, 'P'], [23, 'P'], [25, 'P']],
#  184: [[12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P']],
#  185: [[23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [26, 'P']],
#  186: [[23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P']],
#  187: [[25, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [26, 'P'],
#   [18, 'D']],
#  188: [[23, 'P'], [10, 'P']],
#  189: [[18, 'D'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P']],
#  190: [[25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  191: [[18, 'D'], [10, 'P'], [18, 'D'], [12, 'P'], [25, 'P']],
#  192: [[10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  193: [[12, 'P'], [18, 'D'], [10, 'P'], [10, 'P'], [10, 'P'], [23, 'P']],
#  194: [[10, 'P'], [12, 'P'], [18, 'D'], [23, 'P']],
#  195: [[26, 'P'], [10, 'P'], [26, 'P'], [10, 'P'], [25, 'P'], [23, 'P']],
#  196: [[12, 'P'], [10, 'P']],
#  197: [[18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  198: [[16, 'E'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P']],
#  199: [[25, 'P'], [12, 'P'], [12, 'P'], [25, 'P'], [12, 'P'], [23, 'P']],
#  200: [[10, 'P'], [10, 'P'], [10, 'P'], [25, 'P']],
#  201: [[10, 'P'], [18, 'D']],
#  202: [[25, 'P'], [18, 'D']],
#  203: [[23, 'P'], [25, 'P'], [10, 'P'], [7, 'L']],
#  204: [[25, 'P'], [23, 'P'], [10, 'P']],
#  205: [[25, 'P'], [12, 'P'], [10, 'P'], [23, 'P']],
#  206: [[12, 'P'], [25, 'P']],
#  207: [[25, 'P'], [10, 'P']],
#  208: [[12, 'P'], [25, 'P'], [26, 'P'], [23, 'P']],
#  209: [[18, 'D'], [23, 'P'], [10, 'P'], [12, 'P']],
#  210: [[12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [21, 'R'],
#   [23, 'P']],
#  211: [[12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [26, 'P']],
#  212: [[18, 'D'], [23, 'P']],
#  213: [[12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [28, 'S'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P']],
#  214: [[12, 'P'], [23, 'P'], [12, 'P'], [10, 'P']],
#  215: [[10, 'P'], [26, 'P']],
#  216: [[18, 'D'],
#   [12, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P']],
#  217: [[10, 'P'], [18, 'D']],
#  218: [[18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [12, 'P']],
#  219: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [0, 'N'],
#   [13, 'G']],
#  220: [[10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  221: [[10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [10, 'P']],
#  222: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [13, 'G']],
#  223: [[23, 'P'], [25, 'P'], [10, 'P'], [12, 'P']],
#  224: [[10, 'P'], [18, 'D']],
#  225: [[12, 'P'], [12, 'P'], [22, 'T'], [23, 'P']],
#  226: [[23, 'P'], [10, 'P']],
#  227: [[18, 'D'], [18, 'D'], [23, 'P'], [18, 'D'], [18, 'D'], [10, 'P']],
#  228: [[10, 'G'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [20, 'K'],
#   [10, 'P'],
#   [26, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P']],
#  229: [[12, 'P'], [10, 'P'], [25, 'P']],
#  230: [[12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P']],
#  231: [[12, 'P'], [12, 'P'], [18, 'D']],
#  232: [[18, 'D'], [18, 'D'], [10, 'P'], [23, 'P']],
#  233: [[25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P']],
#  234: [[12, 'P'], [25, 'P'], [18, 'D'], [10, 'P']],
#  235: [[18, 'D'], [25, 'P'], [10, 'P']],
#  236: [[25, 'P'], [12, 'P'], [23, 'P'], [10, 'P']],
#  237: [[23, 'P'], [10, 'P'], [18, 'D'], [25, 'P'], [10, 'P'], [13, 'G']],
#  238: [[23, 'P'], [12, 'P'], [12, 'P'], [12, 'P'], [25, 'P'], [10, 'P']],
#  239: [[23, 'P'], [25, 'P'], [12, 'P'], [25, 'P'], [10, 'P']],
#  240: [[10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [22, 'T'],
#   [18, 'D']],
#  241: [[10, 'P'], [13, 'G'], [12, 'P'], [25, 'P'], [18, 'D']],
#  242: [[18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [12, 'P']],
#  243: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P']],
#  244: [[12, 'P'], [18, 'D']],
#  245: [[10, 'P'], [26, 'P']],
#  246: [[12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P']],
#  247: [[10, 'P'], [18, 'D']],
#  248: [[10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P']],
#  249: [[25, 'P'], [25, 'P'], [12, 'P'], [10, 'P'], [18, 'D']]}

# %%
df_of_actions = pd.concat([pd.DataFrame(actions_taken[i],columns=['position','amino_acid']) for i in actions_taken.keys()])

# %%
with open('delete.pl')

# %%
actions_taken
# Out:
# {0: [[18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [24, 'F'],
#   [25, 'P']],
#  1: [[25, 'P'], [10, 'P']],
#  2: [[12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'D'],
#   [22, 'T'],
#   [10, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  3: [[23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P']],
#  4: [[10, 'P'], [18, 'D'], [25, 'P']],
#  5: [[10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [25, 'P']],
#  6: [[25, 'P'], [11, 'M'], [12, 'P'], [18, 'D'], [10, 'P']],
#  7: [[12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P']],
#  8: [[25, 'P'], [18, 'D'], [18, 'D'], [10, 'P']],
#  9: [[12, 'P'], [23, 'P']],
#  10: [[18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P']],
#  11: [[10, 'P'], [23, 'P']],
#  12: [[23, 'P'], [23, 'P'], [12, 'P']],
#  13: [[10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [22, 'T']],
#  14: [[22, 'T'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  15: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D']],
#  16: [[23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  17: [[10, 'P'], [12, 'P'], [18, 'D'], [12, 'P'], [26, 'P'], [25, 'P']],
#  18: [[25, 'P'], [23, 'P'], [10, 'P']],
#  19: [[10, 'P'], [23, 'P'], [18, 'D']],
#  20: [[10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  21: [[18, 'D'], [23, 'P'], [18, 'D'], [23, 'P'], [12, 'P'], [10, 'P']],
#  22: [[12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  23: [[10, 'P'], [12, 'P'], [18, 'D'], [12, 'P'], [23, 'P']],
#  24: [[10, 'P'], [18, 'D'], [25, 'P']],
#  25: [[29, 'L'], [10, 'P'], [25, 'P'], [25, 'P'], [25, 'P'], [18, 'D']],
#  26: [[12, 'P'], [18, 'D'], [10, 'P'], [23, 'P']],
#  27: [[26, 'P'], [25, 'P'], [10, 'P'], [23, 'P']],
#  28: [[18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [1, 'Y']],
#  29: [[23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D']],
#  30: [[18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D']],
#  31: [[12, 'P'], [10, 'P'], [23, 'P'], [26, 'P']],
#  32: [[25, 'P'], [10, 'P'], [12, 'P'], [10, 'P'], [12, 'P'], [18, 'D']],
#  33: [[10, 'P'], [25, 'P'], [25, 'P'], [10, 'P'], [18, 'D'], [23, 'P']],
#  34: [[18, 'D'], [12, 'P'], [23, 'P']],
#  35: [[12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P']],
#  36: [[10, 'P'], [23, 'P']],
#  37: [[21, 'D'], [18, 'D'], [10, 'P']],
#  38: [[18, 'D'], [25, 'P'], [18, 'D'], [10, 'P']],
#  39: [[12, 'P'], [12, 'P'], [12, 'P'], [10, 'P']],
#  40: [[18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [22, 'T'],
#   [18, 'D']],
#  41: [[18, 'D'], [18, 'D'], [12, 'P']],
#  42: [[23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P']],
#  43: [[12, 'P'], [10, 'P'], [10, 'P'], [23, 'P']],
#  44: [[10, 'P'], [18, 'D'], [25, 'P'], [23, 'P']],
#  45: [[25, 'P'], [25, 'P'], [23, 'P'], [23, 'P'], [25, 'P'], [12, 'P']],
#  46: [[23, 'P'], [23, 'P'], [12, 'P'], [18, 'D']],
#  47: [[10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [20, 'G'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  48: [[10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D']],
#  49: [[18, 'D'], [10, 'P'], [10, 'P'], [10, 'P'], [12, 'P'], [25, 'P']],
#  50: [[12, 'P'], [25, 'P']],
#  51: [[12, 'P'], [10, 'P'], [25, 'P']],
#  52: [[12, 'P'], [12, 'P'], [18, 'D']],
#  53: [[25, 'P'], [12, 'P'], [12, 'P'], [12, 'P'], [23, 'P']],
#  54: [[25, 'P'], [10, 'P']],
#  55: [[18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [7, 'P'],
#   [12, 'P']],
#  56: [[18, 'D'], [23, 'P']],
#  57: [[25, 'P'], [18, 'D'], [12, 'P']],
#  58: [[23, 'P'], [18, 'D'], [10, 'P']],
#  59: [[12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [13, 'G'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  60: [[18, 'D'], [10, 'P'], [22, 'T'], [12, 'P'], [12, 'P'], [25, 'P']],
#  61: [[10, 'P'], [18, 'D'], [12, 'P'], [23, 'P']],
#  62: [[23, 'P'], [10, 'P'], [18, 'D']],
#  63: [[18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P']],
#  64: [[10, 'P'], [10, 'P'], [10, 'P'], [10, 'P'], [23, 'P']],
#  65: [[12, 'P'], [12, 'P'], [23, 'P']],
#  66: [[12, 'P'], [25, 'P'], [23, 'P']],
#  67: [[10, 'P'], [10, 'P'], [12, 'P'], [25, 'P']],
#  68: [[10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [26, 'P']],
#  69: [[18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [0, 'N'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [13, 'G']],
#  70: [[25, 'P'], [12, 'P']],
#  71: [[23, 'P'], [12, 'P'], [10, 'P'], [23, 'P'], [12, 'P'], [18, 'D']],
#  72: [[18, 'D'], [25, 'P']],
#  73: [[10, 'P'], [12, 'P']],
#  74: [[18, 'D'], [18, 'D']],
#  75: [[23, 'P'], [12, 'P'], [18, 'D'], [12, 'P'], [10, 'P']],
#  76: [[10, 'P'], [23, 'P']],
#  77: [[23, 'P'], [18, 'D'], [25, 'P'], [23, 'P'], [10, 'P']],
#  78: [[12, 'P'], [18, 'D']],
#  79: [[22, 'T'], [18, 'D'], [10, 'P'], [10, 'P'], [12, 'P']],
#  80: [[10, 'P'], [25, 'P'], [12, 'P']],
#  81: [[10, 'P'], [18, 'D'], [25, 'P'], [25, 'P'], [23, 'P'], [26, 'P']],
#  82: [[23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D']],
#  83: [[12, 'P'], [18, 'D'], [12, 'P'], [23, 'P']],
#  84: [[18, 'D'], [13, 'H']],
#  85: [[23, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [11, 'Y'],
#   [12, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [23, 'P'],
#   [12, 'P']],
#  86: [[26, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [25, 'P'],
#   [10, 'P']],
#  87: [[10, 'P'], [25, 'P'], [18, 'D']],
#  88: [[23, 'P'], [12, 'P'], [10, 'P'], [12, 'P'], [23, 'P'], [18, 'D']],
#  89: [[12, 'P'], [23, 'P']],
#  90: [[10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  91: [[23, 'P'], [10, 'P']],
#  92: [[12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  93: [[23, 'P'], [25, 'P'], [10, 'P'], [23, 'P'], [22, 'T']],
#  94: [[10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P']],
#  95: [[25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [22, 'T'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P']],
#  96: [[18, 'D'], [12, 'P'], [12, 'P'], [10, 'P'], [18, 'D'], [25, 'P']],
#  97: [[18, 'D'], [10, 'P'], [12, 'P'], [12, 'P'], [18, 'D'], [23, 'P']],
#  98: [[18, 'D'], [23, 'P']],
#  99: [[26, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P']],
#  100: [[23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [18, 'D'],
#   [27, 'V'],
#   [25, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [27, 'V'],
#   [23, 'P']],
#  101: [[23, 'P'], [10, 'P']],
#  102: [[25, 'P'], [18, 'D'], [10, 'P']],
#  103: [[23, 'P'], [18, 'D'], [11, 'Y'], [12, 'P'], [23, 'P'], [10, 'P']],
#  104: [[10, 'P'], [23, 'P']],
#  105: [[10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P']],
#  106: [[12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [27, 'V'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  107: [[12, 'P'], [23, 'P'], [25, 'P']],
#  108: [[10, 'P'], [12, 'P'], [23, 'P'], [10, 'P'], [25, 'P']],
#  109: [[25, 'P'], [10, 'P'], [10, 'P'], [12, 'P'], [18, 'D']],
#  110: [[10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  111: [[12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  112: [[10, 'P'], [23, 'P'], [18, 'D'], [23, 'P'], [12, 'P']],
#  113: [[12, 'P'], [18, 'D']],
#  114: [[25, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  115: [[23, 'P'], [25, 'P']],
#  116: [[18, 'E'], [12, 'P'], [10, 'P'], [12, 'P'], [25, 'P']],
#  117: [[18, 'D'], [10, 'P'], [12, 'P']],
#  118: [[18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [20, 'G']],
#  119: [[23, 'P'], [18, 'D'], [18, 'D'], [12, 'P']],
#  120: [[13, 'G'], [18, 'D']],
#  121: [[10, 'P'], [12, 'P']],
#  122: [[23, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P']],
#  123: [[10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  124: [[25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  125: [[10, 'P'], [10, 'P'], [12, 'P'], [22, 'T']],
#  126: [[10, 'P'], [10, 'P'], [25, 'P']],
#  127: [[10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [22, 'T'],
#   [10, 'P'],
#   [18, 'D']],
#  128: [[18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [22, 'T'],
#   [10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P']],
#  129: [[10, 'P'], [10, 'P'], [18, 'D'], [25, 'P']],
#  130: [[10, 'P'], [12, 'P']],
#  131: [[12, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  132: [[10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P']],
#  133: [[25, 'P'],
#   [26, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  134: [[18, 'F'], [25, 'P'], [10, 'P'], [12, 'P'], [23, 'P'], [18, 'D']],
#  135: [[25, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  136: [[12, 'P'], [23, 'P']],
#  137: [[12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P']],
#  138: [[10, 'P'], [12, 'P']],
#  139: [[23, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  140: [[18, 'D'], [10, 'P'], [25, 'P'], [10, 'P'], [23, 'P']],
#  141: [[25, 'P'], [12, 'P'], [25, 'P'], [25, 'P'], [25, 'P'], [10, 'P']],
#  142: [[10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [22, 'T'],
#   [10, 'P'],
#   [26, 'P'],
#   [12, 'P']],
#  143: [[23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  144: [[23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [23, 'P']],
#  145: [[10, 'P'], [10, 'P'], [23, 'P'], [26, 'P'], [23, 'P'], [18, 'D']],
#  146: [[23, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [26, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P']],
#  147: [[23, 'P'], [25, 'P'], [23, 'P'], [10, 'P'], [18, 'D']],
#  148: [[12, 'P'], [26, 'P']],
#  149: [[26, 'P'], [10, 'P'], [23, 'P'], [25, 'P'], [12, 'P']],
#  150: [[18, 'D'], [12, 'P'], [23, 'P']],
#  151: [[25, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [25, 'P']],
#  152: [[23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [22, 'T'],
#   [25, 'P']],
#  153: [[18, 'D'], [23, 'P'], [18, 'P'], [23, 'P'], [10, 'P']],
#  154: [[10, 'P'], [25, 'P'], [25, 'P'], [13, 'G']],
#  155: [[12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [13, 'G'],
#   [12, 'G'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P']],
#  156: [[25, 'P'], [12, 'P']],
#  157: [[25, 'P'], [18, 'D']],
#  158: [[12, 'P'], [23, 'P'], [12, 'P'], [10, 'P']],
#  159: [[10, 'P'], [18, 'D'], [18, 'D'], [10, 'P'], [25, 'P']],
#  160: [[12, 'P'], [23, 'P']],
#  161: [[10, 'P'], [18, 'D']],
#  162: [[23, 'P'], [12, 'P'], [10, 'P'], [12, 'P'], [18, 'D']],
#  163: [[12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [26, 'P']],
#  164: [[10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D']],
#  165: [[26, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [12, 'P']],
#  166: [[18, 'D'], [10, 'P']],
#  167: [[10, 'P'], [18, 'D'], [25, 'P'], [23, 'P']],
#  168: [[10, 'P'], [18, 'D']],
#  169: [[10, 'P'], [22, 'T'], [10, 'P'], [10, 'P'], [12, 'P'], [23, 'P']],
#  170: [[18, 'D'], [25, 'P'], [23, 'P'], [12, 'P']],
#  171: [[10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [18, 'D']],
#  172: [[25, 'P'], [10, 'P']],
#  173: [[22, 'T'], [18, 'D'], [10, 'P'], [10, 'P'], [10, 'P'], [25, 'P']],
#  174: [[12, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  175: [[12, 'P'], [18, 'D'], [29, 'V'], [25, 'P'], [10, 'P']],
#  176: [[23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P']],
#  177: [[18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [24, 'F'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P']],
#  178: [[23, 'P'], [12, 'P'], [23, 'P'], [12, 'P'], [10, 'P']],
#  179: [[26, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P']],
#  180: [[10, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D']],
#  181: [[12, 'P'], [23, 'P'], [12, 'P'], [25, 'P'], [25, 'P'], [18, 'D']],
#  182: [[10, 'P'], [18, 'D'], [18, 'D'], [10, 'P'], [23, 'P']],
#  183: [[10, 'P'], [10, 'P'], [23, 'P'], [25, 'P']],
#  184: [[12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P']],
#  185: [[23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [26, 'P']],
#  186: [[23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [10, 'P']],
#  187: [[25, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [26, 'P'],
#   [18, 'D']],
#  188: [[23, 'P'], [10, 'P']],
#  189: [[18, 'D'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P']],
#  190: [[25, 'P'],
#   [12, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [26, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [10, 'P']],
#  191: [[18, 'D'], [10, 'P'], [18, 'D'], [12, 'P'], [25, 'P']],
#  192: [[10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P']],
#  193: [[12, 'P'], [18, 'D'], [10, 'P'], [10, 'P'], [10, 'P'], [23, 'P']],
#  194: [[10, 'P'], [12, 'P'], [18, 'D'], [23, 'P']],
#  195: [[26, 'P'], [10, 'P'], [26, 'P'], [10, 'P'], [25, 'P'], [23, 'P']],
#  196: [[12, 'P'], [10, 'P']],
#  197: [[18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  198: [[16, 'E'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P']],
#  199: [[25, 'P'], [12, 'P'], [12, 'P'], [25, 'P'], [12, 'P'], [23, 'P']],
#  200: [[10, 'P'], [10, 'P'], [10, 'P'], [25, 'P']],
#  201: [[10, 'P'], [18, 'D']],
#  202: [[25, 'P'], [18, 'D']],
#  203: [[23, 'P'], [25, 'P'], [10, 'P'], [7, 'L']],
#  204: [[25, 'P'], [23, 'P'], [10, 'P']],
#  205: [[25, 'P'], [12, 'P'], [10, 'P'], [23, 'P']],
#  206: [[12, 'P'], [25, 'P']],
#  207: [[25, 'P'], [10, 'P']],
#  208: [[12, 'P'], [25, 'P'], [26, 'P'], [23, 'P']],
#  209: [[18, 'D'], [23, 'P'], [10, 'P'], [12, 'P']],
#  210: [[12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [21, 'R'],
#   [23, 'P']],
#  211: [[12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [26, 'P']],
#  212: [[18, 'D'], [23, 'P']],
#  213: [[12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [26, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [28, 'S'],
#   [12, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P']],
#  214: [[12, 'P'], [23, 'P'], [12, 'P'], [10, 'P']],
#  215: [[10, 'P'], [26, 'P']],
#  216: [[18, 'D'],
#   [12, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P']],
#  217: [[10, 'P'], [18, 'D']],
#  218: [[18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [26, 'P'],
#   [12, 'P']],
#  219: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [0, 'N'],
#   [13, 'G']],
#  220: [[10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [12, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D']],
#  221: [[10, 'P'],
#   [18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [10, 'P']],
#  222: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [25, 'P'],
#   [25, 'P'],
#   [13, 'G']],
#  223: [[23, 'P'], [25, 'P'], [10, 'P'], [12, 'P']],
#  224: [[10, 'P'], [18, 'D']],
#  225: [[12, 'P'], [12, 'P'], [22, 'T'], [23, 'P']],
#  226: [[23, 'P'], [10, 'P']],
#  227: [[18, 'D'], [18, 'D'], [23, 'P'], [18, 'D'], [18, 'D'], [10, 'P']],
#  228: [[10, 'G'],
#   [12, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [20, 'K'],
#   [10, 'P'],
#   [26, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P']],
#  229: [[12, 'P'], [10, 'P'], [25, 'P']],
#  230: [[12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P']],
#  231: [[12, 'P'], [12, 'P'], [18, 'D']],
#  232: [[18, 'D'], [18, 'D'], [10, 'P'], [23, 'P']],
#  233: [[25, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [25, 'P'],
#   [25, 'P'],
#   [10, 'P']],
#  234: [[12, 'P'], [25, 'P'], [18, 'D'], [10, 'P']],
#  235: [[18, 'D'], [25, 'P'], [10, 'P']],
#  236: [[25, 'P'], [12, 'P'], [23, 'P'], [10, 'P']],
#  237: [[23, 'P'], [10, 'P'], [18, 'D'], [25, 'P'], [10, 'P'], [13, 'G']],
#  238: [[23, 'P'], [12, 'P'], [12, 'P'], [12, 'P'], [25, 'P'], [10, 'P']],
#  239: [[23, 'P'], [25, 'P'], [12, 'P'], [25, 'P'], [10, 'P']],
#  240: [[10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [22, 'T'],
#   [18, 'D']],
#  241: [[10, 'P'], [13, 'G'], [12, 'P'], [25, 'P'], [18, 'D']],
#  242: [[18, 'D'],
#   [18, 'D'],
#   [23, 'P'],
#   [10, 'P'],
#   [23, 'P'],
#   [23, 'P'],
#   [25, 'P'],
#   [23, 'P'],
#   [18, 'D'],
#   [18, 'D'],
#   [18, 'D'],
#   [18, 'D'],
#   [25, 'P'],
#   [12, 'P']],
#  243: [[10, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P']],
#  244: [[12, 'P'], [18, 'D']],
#  245: [[10, 'P'], [26, 'P']],
#  246: [[12, 'P'],
#   [12, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [18, 'D'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P']],
#  247: [[10, 'P'], [18, 'D']],
#  248: [[10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [12, 'P'],
#   [18, 'D'],
#   [10, 'P'],
#   [10, 'P'],
#   [12, 'P'],
#   [23, 'P'],
#   [10, 'P'],
#   [10, 'P'],
#   [23, 'P']],
#  249: [[25, 'P'], [25, 'P'], [12, 'P'], [10, 'P'], [18, 'D']]}

# %%
df_of_actions
# Out:
#     position amino_acid
# 0         18          D
# 1         23          P
# 2         10          P
# 3         12          P
# 4         23          P
# ..       ...        ...
# 0         25          P
# 1         25          P
# 2         12          P
# 3         10          P
# 4         18          D
#
# [1693 rows x 2 columns]

# %%
df_of_actions
# Out:
#     position amino_acid
# 0         18          D
# 1         23          P
# 2         10          P
# 3         12          P
# 4         23          P
# ..       ...        ...
# 0         25          P
# 1         25          P
# 2         12          P
# 3         10          P
# 4         18          D
#
# [1693 rows x 2 columns]

# %%
df_of_actions
# Out:
#     position amino_acid
# 0         18          D
# 1         23          P
# 2         10          P
# 3         12          P
# 4         23          P
# ..       ...        ...
# 0         25          P
# 1         25          P
# 2         12          P
# 3         10          P
# 4         18          D
#
# [1693 rows x 2 columns]

# %%
pd.DataFrame(df_of_actions['amino_acid'].value_counts()).reset_index().rename(columns={'index':'amino_acid','amino_acid':'frequency'})
# Out:
#    amino_acid  frequency
# 0           P       1360
# 1           D        282
# 2           T         17
# 3           G         13
# 4           V          4
# 5           F          3
# 6           Y          3
# 7           L          2
# 8           N          2
# 9           E          2
# 10          M          1
# 11          H          1
# 12          R          1
# 13          S          1
# 14          K          1

# %%
list_of_beta_percentages = []
for file in glob.glob('validation_structures/entropy_*/*.pdb'):
    beta_percentage = percentage_of_b(get_structural_annotations(file))
    list_of_beta_percentages.append([file,beta_percentage])

# %%
df_beta = pd.DataFrame(list_of_beta_percentages,columns=['path','percentage'])

# %%
df_beta[df_beta['percentage']>40].sort_values(by='percentage')
# Out:
#                                                    path  percentage
# 1056  validation_structures/entropy_0.0_co_50.0/2h89...   43.333333
# 1857  validation_structures/entropy_0.001_co_30.0/4k...   43.333333
# 1977  validation_structures/entropy_0.001_co_30.0/2y...   43.333333
# 4913  validation_structures/entropy_1e-05_co_30.0/1z...   43.333333
# 580   validation_structures/entropy_0.0_co_30.0/3mde...   46.666667
# 1677  validation_structures/entropy_0.001_co_30.0/3a...   50.000000
# 2739  validation_structures/entropy_0.0001_co_30.0/4...   50.000000
# 5395  validation_structures/entropy_0.001_co_50.0/4i...   50.000000
# 2670  validation_structures/entropy_0.0001_co_30.0/4...   60.000000
# 3604  validation_structures/entropy_0.0001_co_50.0/4...   66.666667

# %%
df_beta.iloc[1677]['path']
# Out:
# 'validation_structures/entropy_0.001_co_30.0/3ayg_A_1_434_463_2024-01-21 00:40:46.pdb'
